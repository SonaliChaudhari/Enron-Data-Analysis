# %%
import os
import time
import requests
from pprint import pprint
import json
from datetime import datetime
import glob
import string

# %%
cur_path = os.path.dirname(os.getcwd())
path = cur_path + '/data/nyt_data'

# %%
key1 = os.environ.get('APIKEY')
print(key1)
# Out:
# b324099437864f3bb87f6e2e163b3ae4

# %%
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?q=new+york+times&sort=newest&api-key="+(key1)+"&begin_date=20010911&end_date=20011231"

# %%
def getJsonFileName(date, page, json_file_path):
    json_file_name = ".".join([date,str(page),'json'])
    json_file_name = "".join([json_file_path,json_file_name])
    return json_file_name
 
# helpful function for processing keywords, mostly    

# get the articles from the NYTimes Article API    
#def getArticles(date, api_key, json_file_path):
    # LOOP THROUGH THE 101 PAGES NYTIMES ALLOWS FOR THAT DATE

# %%
i = 0
response_data = []
for i in range(100):
    try:
        response_data.append(requests.get(url).json())
        i += 1
        time.sleep(3)
    except ValueError:
        continue

# %%
response_data
# Out:
# [{'copyright': 'Copyright (c) 2013 The New York Times Company.  All Rights Reserved.',
#   'response': {'docs': [{'_id': '4fd218eb8eb7c8105d79642d',
#      'abstract': 'James Barron article recalls notable events of 2001, year that began quietly but was ultimately dominated by terrorist attacks of Sept 11; photos (Special section The Year in Pictures) (M)',
#      'blog': [],
#      'byline': {'original': 'By JAMES BARRON',
#       'person': [{'firstname': 'James',
#         'lastname': 'BARRON',
#         'organization': '',
#         'rank': 1,
#         'role': 'reported'}]},
#      'document_type': 'article',
#      'headline': {'main': "The Year in Pictures: IN THE TOWERS' SHADOW"},
#      'keywords': [{'name': 'glocations', 'value': 'NEW YORK CITY'},
#       {'name': 'glocations', 'value': 'WASHINGTON (DC)'},
#       {'name': 'subject', 'value': 'WORLD TRADE CENTER (NYC)'},
#       {'name': 'subject', 'value': 'AIRLINES AND AIRPLANES'},
# ...

# %%
articles_path = path + '/article2011/'
for json_file in response_data:
    with open(articles_path + 'article_search_'+ str(datetime.now()) +'.json', 'w') as outfile:
        json.dump(json_file, outfile)
        time.sleep(3)

# %%
import glob
json_file_path = articles_path +'/*'
lambda_file = lambda json_file_path : glob.glob(json_file_path)

# %%
article_search_dict = {}
for json_file in lambda_file(json_file_path):
    with open(json_file) as json_data:
        article_search_dict.update(json.load(json_data))
    pprint(article_search_dict)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-71-ca95799d8eb0> in <module>()
#       2 for json_file in lambda_file(json_file_path):
#       3     with open(json_file) as json_data:
# ----> 4         article_search_dict.update(json.load(json_data))
#       5     pprint(article_search_dict)
#
# /Users/sonalichaudhari/anaconda/lib/python3.5/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     266         cls=cls, object_hook=object_hook,
#     267         parse_float=parse_float, parse_int=parse_int,
# --> 268         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     269
#     270
#
# /Users/sonalichaudhari/anaconda/lib/python3.5/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
# ...
