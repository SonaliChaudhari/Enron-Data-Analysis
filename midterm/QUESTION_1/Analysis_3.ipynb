# %%
import nltk
import tarfile
import email
from os.path import splitext
import glob
from os.path import basename
from email.parser import Parser
from collections import Counter

# %%
# Analysis 1: Number of mail received and sent by each Employee
file = glob.glob('/Users/sonalichaudhari/Desktop/midterm/data/enron/maildir/*')
for f in file:
    person_name = basename(f)
    print(person_name)
    ppath = glob.glob(f+'/*')
    for folders in ppath:
        email_types=folders.split(name)
        print(email_types)
        #sppath = glob.glob(email_types+'/*')
        #or s in sppath:
           # final = d.split(email_types)
        #a = basename(email_types)
        #print(a)
        #if email_types=='sent':
            #Sent=glob.glob(email_types+'/*')
            #print(filesSent)
# Out:
# allen-p
# ['/Users/sonalichaudhari/Desktop/midterm/data/enron/maildir/allen-p/_sent_mail']
# ['/Users/sonalichaudhari/Desktop/midterm/data/enron/maildir/allen-p/all_documents']
# ['/Users/sonalichaudhari/Desktop/midterm/data/enron/maildir/allen-p/contacts']
# ['/Users/sonalichaudhari/Desktop/midterm/data/enron/maildir/allen-p/deleted_items']
# ['/Users/sonalichaudhari/Desktop/midterm/data/enron/maildir/allen-p/discussion_threads']
# ['/Users/sonalichaudhari/Desktop/midterm/data/enron/maildir/allen-p/inbox']
# ['/Users/sonalichaudhari/Desktop/midterm/data/enron/maildir/allen-p/notes_inbox']
# ['/Users/sonalichaudhari/Desktop/midterm/data/enron/maildir/allen-p/sent']
# ['/Users/sonalichaudhari/Desktop/midterm/data/enron/maildir/allen-p/sent_items']
# ['/Users/sonalichaudhari/Desktop/midterm/data/enron/maildir/allen-p/straw']
# arnold-j
# ['/Users/sonalichaudhari/Desktop/midterm/data/enron/maildir/arnold-j/2000_conference']
# ...
